# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

# %%
np.random.seed(500)  #random seed

# %%
Corpus_csv = pd.read_csv("imdb_tr.csv",encoding='latin-1') #read csv file

# %%
Corpus_csv['text'].dropna(inplace=True)# All text to lower case. This is required as python interprets 'dog' and 'DOG' differently
Corpus_csv['text'] = [entry.lower() for entry in Corpus_csv['text']]# broken into words
Corpus_csv['text']= [word_tokenize(entry) for entry in Corpus_csv['text']]# Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tagmap = defaultdict(lambda : wn.NOUN) #default  dictionary
tagmap['J'] = wn.ADJ
tagmap['V'] = wn.VERB
tagmap['R'] = wn.ADV
for index,entry in enumerate(Corpus_csv['text']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer() converting to its base form
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tagmap[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    Corpus_csv.loc[index,'text_final'] = str(Final_words)

# %%
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(Corpus_csv['text_final'],Corpus_csv['polarity'],test_size=0.3)

# %%
Encoder_le = LabelEncoder() #convert to machine readable form
Train_Y = Encoder_le.fit_transform(Train_Y) 
Test_Y = Encoder_le.fit_transform(Test_Y)

# %%
Tfidf_vect = TfidfVectorizer(max_features=5000) #to convert text into features
Tfidf_vect.fit(Corpus_csv['text_final']) 
Train_X_Tfidf = Tfidf_vect.transform(Train_X) #to transform and replace it with new 
Test_X_Tfidf = Tfidf_vect.transform(Test_X)  #to transform and replace it with new

# %%
print(Tfidf_vect.vocabulary_) #print new features
# Out:
# {'first': 1727, 'think': 4494, 'another': 192, 'disney': 1288, 'movie': 2935, 'might': 2839, 'good': 1943, 'kid': 2477, 'watch': 4851, 'ca': 611, 'help': 2086, 'enjoy': 1485, 'age': 90, 'love': 2665, 'saw': 3868, 'year': 4983, 'later': 2531, 'still': 4260, 'danny': 1113, 'glover': 1929, 'superb': 4355, 'could': 1004, 'play': 3325, 'part': 3214, 'well': 4879, 'christopher': 778, 'lloyd': 2630, 'hilarious': 2105, 'perfect': 3257, 'tony': 4555, 'believable': 402, 'mel': 2801, 'clark': 802, 'give': 1918, 'put': 3531, 'aside': 258, 'house': 2167, 'repeat': 3686, 'miss': 2875, 'desperate': 1212, 'housewife': 2169, 'new': 3015, 'one': 3122, 'know': 2498, 'exactly': 1559, 'plague': 3317, 'never': 3013, 'say': 3869, 'want': 4834, 'minute': 2866, 'fame': 1643, 'br': 521, 'script': 3903, 'direction': 1259, 'recognize': 3620, 'actor': 46, 'usual': 4737, 'suspect': 4382, 'marshall': 2749, 'class': 805, 'addition': 58, 'sit': 4074, 'cheesy': 746, 'flick': 1748, 'boy': 516, 'wrong': 4975, 'favorite': 1671, 'office': 3109, 'girl': 1915, 'make': 2713, 'card': 650, 'lol': 2641, 'computer': 909, 'like': 2601, 'someone': 4138, 'identify': 2205, 'next': 3021, 'device': 1229, 'even': 1539, 'dinosaur': 1254, 'much': 2938, 'time': 4528, 'waste': 4849, 'big': 433, 'fan': 1647, 'stephen': 4251, 'king': 2486, 'work': 4954, 'film': 1709, 'great': 1971, 'pet': 3274, 'family': 1645, 'move': 2933, 'seem': 3928, 'happy': 2038, 'cemetery': 699, 'behind': 397, 'neighbor': 3000, 'fred': 1816, 'explain': 1597, 'ground': 1990, 'pure': 3524, 'evil': 1553, 'tell': 4456, 'louis': 2661, 'bury': 595, 'human': 2181, 'kind': 2484, 'would': 4965, 'come': 866, 'back': 328, 'life': 2593, 'problem': 3463, 'person': 3267, 'soon': 4146, 'everything': 1548, 'start': 4234, 'go': 1932, 'hell': 2083, 'wont': 4948, 'anymore': 205, 'away': 316, 'main': 2707, 'act': 40, 'pretty': 3437, 'need': 2996, 'little': 2625, 'bit': 444, 'story': 4274, 'mainly': 2708, 'original': 3141, 'feature': 1679, 'lot': 2657, 'effect': 1421, 'way': 4860, 'eerie': 1420, 'frighten': 1831, 'basic': 362, 'reason': 3609, 'send': 3938, 'chill': 759, 'fact': 1626, 'character': 725, 'truly': 4633, 'particular': 3218, 'pop': 3363, 'three': 4508, 'rachel': 3552, 'sister': 4073, 'pass': 3224, 'haunt': 2056, 'appear': 218, 'generally': 1886, 'scary': 3875, 'talk': 4422, 'anything': 207, 'second': 3913, 'bad': 333, 'honest': 2138, 'scar': 3871, 'live': 2627, 'absolutely': 9, 'nothing': 3066, 'almost': 133, 'delivers': 1175, 'scare': 3872, 'acting': 42, 'rate': 3585, 'plot': 3337, 'mesmerize': 2822, 'horror': 2159, 'horrid': 2156, 'thing': 4493, 'tv': 4643, 'see': 3923, 'get': 1904, 'frankly': 1814, 'low': 2669, 'bar': 350, 'compose': 905, 'lame': 2519, 'obvious': 3095, 'attempt': 284, 'create': 1033, 'news': 3019, 'bear': 376, 'embarrass': 1450, 'prize': 3460, 'list': 2619, 'since': 4060, 'let': 2583, 'ice': 2200, 'funny': 1851, 'enjoyed': 1487, 'terrific': 4470, 'jeff': 2399, 'talent': 4420, 'change': 720, 'end': 1472, 'death': 1141, 'creature': 1039, 'far': 1652, 'gruesome': 1995, 'sci': 3884, 'fi': 1694, 'interest': 2333, 'religious': 3666, 'message': 2824, 'obviously': 3096, 'figure': 1705, 'shark': 3989, 'prefer': 3414, 'represent': 3693, 'particularly': 3219, 'frightening': 1832, 'scene': 3877, 'world': 4956, 'feel': 1681, 'third': 4496, 'view': 4784, 'classic': 806, 'many': 2732, 'people': 3253, 'wo': 4942, 'reference': 3638, 'christianity': 774, 'close': 827, 'memory': 2809, 'last': 2528, 'hunt': 2191, 'stick': 4258, 'ahead': 97, 'others': 3149, 'address': 60, 'treatment': 4608, 'native': 2980, 'environment': 1506, 'ever': 1543, 'present': 3426, 'contrast': 965, 'short': 4016, 'long': 2646, 'term': 4467, 'greed': 1974, 'relevant': 3662, 'today': 4540, 'discussion': 1279, 'depth': 1197, 'top': 4558, 'set': 3964, 'beautiful': 382, 'cinematography': 790, 'excellent': 1565, 'day': 1130, 'shakespeare': 3981, 'appreciate': 222, 'ken': 2468, 'branagh': 525, 'do': 1306, 'bring': 550, 'generation': 1888, 'viewer': 478 ...

# %%
print(Train_X_Tfidf) #print occurence
# Out:
#   (0, 4983)	0.0688707175636
#   (0, 4965)	0.0536143018215
#   (0, 4961)	0.0451777046432
#   (0, 4954)	0.0338393780946
#   (0, 4939)	0.0677421285491
#   (0, 4938)	0.123819925129
#   (0, 4928)	0.0747664497376
#   (0, 4923)	0.0580398233481
#   (0, 4897)	0.0883322164721
#   (0, 4879)	0.0537354293088
#   (0, 4822)	0.0538190922559
#   (0, 4739)	0.0722635464183
#   (0, 4738)	0.0561310261182
#   (0, 4737)	0.056440178731
#   (0, 4684)	0.0878176988072
#   (0, 4651)	0.034262260861
#   (0, 4608)	0.0737632198552
#   (0, 4566)	0.122775709462
#   (0, 4509)	0.0671495652615
#   (0, 4508)	0.047391728512
#   (0, 4501)	0.0382373531128
#   (0, 4493)	0.0314654345785
#   (0, 4469)	0.0720131132586
#   (0, 4422)	0.047859288594
#   (0, 4312)	0.0786764684533
#   :	:
#   (17499, 475)	0.0370312691311
#   (17499, 440)	0.0488375375833
#   (17499, 437)	0.0349771503792
#   (17499, 431)	0.0472179832715
#   (17499, 430)	0.0317707068144
#   (17499, 397)	0.0295432300952
#   (17499, 385)	0.068295893506
#   (17499, 381)	0.0494355759187
#   (17499, 333)	0.0160559525686
#   (17499, 316)	0.0241281725224
#   (17499, 314)	0.0347858775758
#   (17499, 250)	0.0370682398576
#   (17499, 239)	0.0225271087778
#   (17499, 231)	0.0476910539374
#   (17499, 218)	0.026637274568
#   (17499, 158)	0.0265426744488
#   (17499, 151)	0.0334714740297
#   (17499, 133)	0.0232884830409
#   (17499, 109)	0.0404355436038
#   (17499, 76)	0.0496465412763
#   (17499, 60)	0.0436773187921
#   (17499, 50)	0.0428213875441
#   (17499, 46)	0.0187909541806
#   (17499, 43)	0.0240553258017
#   (17499, 9)	0.0279440747462
